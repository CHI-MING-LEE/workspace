# %%
import pandas as pd

# %%
# train_raw_18 = pd.read_csv("train_pre_18_fix_index.csv")
# X_test_18 = pd.read_csv("test_pre_18_fix_index.csv")

# train_raw_13 = pd.read_csv("train_pre_13.csv")
# X_test_13 = pd.read_csv("test_pre_13.csv")

train_raw_13 = pd.read_csv("train_pre_13_add_more_ftrs.csv")
X_test_13 = pd.read_csv("test_pre_13_add_more_ftrs.csv")

# %%
other_all_feature = pd.read_csv("all_features_18_other_features_2.csv", index_col=None)
print(other_all_feature.shape)
del other_all_feature['Unnamed: 0']
print(other_all_feature.shape)
# Out:
# (1938653, 7)
# (1938653, 6)

# %%
# all_features_18 = pd.concat([train_raw_18.drop("fraud_ind", axis=1), X_test_18], axis=0)
all_features_13 = pd.concat([train_raw_13.drop("fraud_ind", axis=1), X_test_13], axis=0)

# %%
# print(train_raw_18.shape)
print(train_raw_13.shape)
# print(all_features_18.shape)
print(all_features_13.shape)
# Out:
# (1516988, 103)
# (1938653, 102)

# %%
# train_raw_18.head()
# Out:
#    acqic   bacno    cano    conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038   513.80      0  172652  457  59333      0    102
# 1      0  134508   45725   465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328   513.80      0  152458  457  59333      0    102
# 3   6716  157159   29967  1016.11     62  172946  247  50436   3281    102
# 4   5975  105985   81305   713.66     62  182129  263  93775   5817    102
#
#    ...  latent_7  latent_9  latent_10  latent_11  latent_12  latent_13  \
# 0  ...     0.294     0.155      0.443      0.222      0.000      0.351
# 1  ...     0.236     0.218      0.493      0.282      0.355      0.678
# 2  ...     0.294     0.155      0.443      0.222      0.000      0.351
# 3  ...     0.314     0.072      0.171      0.374      0.045      0.000
# 4  ...     0.219     0.262      0.000      0.839      0.000      0.000
#
#    latent_14  latent_15  latent_16  fraud_ind
# ...

# %%
train_raw_13.head()
# Out:
#    acqic   bacno    cano    conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038   513.80      0  172652  457  59333      0    102
# 1      0  134508   45725   465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328   513.80      0  152458  457  59333      0    102
# 3   6716  157159   29967  1016.11     62  172946  247  50436   3281    102
# 4   5975  105985   81305   713.66     62  182129  263  93775   5817    102
#
#    ...  bacno_cano_conam_rolling_14_window_mean  \
# 0  ...                                  601.579
# 1  ...                                  383.249
# 2  ...                                  568.570
# 3  ...                                    0.000
# 4  ...                                  814.140
#
#    bacno_cano_conam_rolling_7_window_mean  \
# 0                                 524.787
# 1                                 354.677
# 2                                 556.070
# 3                                   0.000
# ...

# %%
other_all_feature.head()
# Out:
#    bacno_cano_7_times_conam_max_by_no  bacno_cano_conam_rolling_14_window_max  \
# 0                             2385.75                                 1458.33
# 1                             1881.93                                  812.26
# 2                              776.57                                  683.25
# 3                             1310.49                                    0.00
# 4                             1159.29                                  814.14
#
#    bacno_cano_14_times_conam_max_by_no  bacno_cano_conam_cumsum_mean  \
# 0                              2385.75                    561.301096
# 1                              1881.93                    355.962083
# 2                              1304.96                    552.063333
# 3                              1830.62                      0.000000
# 4                              1159.29                    814.140000
#
#    bacno_cano_recent_no_5_loctm_acc_min_diff  \
# ...

# %% [markdown]
# ### 將特徵合併至pre13

# %%
pd.read_csv("importance_model_pre_18_fix_index.csv").sort_values("importance", ascending=False)
# Out:
#                                      feature_name  importance
# 1                                           bacno       73901
# 2                                            cano       34634
# 7                                           mchno       17649
# 0                                           acqic       17589
# 6                                             mcc       14249
# 8                                           scity        9059
# 3                                           conam        7905
# 23                              cano_value_counts        6826
# 22                             bacno_value_counts        5019
# 72                  bacno_cnt_by_locdt_loctm_hour        4683
# 40                            conam_mean_by_bacno        3706
# 51                            conam_mean_by_locdt        3384
# 52                        loctm_cnt_mean_by_bacno        3007
# 53                         loctm_cnt_mean_by_cano        2774
# ...

# %% [markdown]
# #### 1. bacno_cano_recent_no_5_loctm_acc_min_diff 最近5次的交易時間差平均

# %%
# all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_recent_no_5_loctm_acc_min_diff"]], axis=1)
# all_features_13.head(3)
# Out:
#         acqic   bacno    cano    conam  csmcu   loctm  mcc  mchno  scity  \
# 0        6881  113261   38038   513.80      0  172652  457  59333      0
# 1           0  134508   45725   465.62      0  105114  451      0   5817
# 2        6881   15408  188328   513.80      0  152458  457  59333      0
# 3        6716  157159   29967  1016.11     62  172946  247  50436   3281
# 4        5975  105985   81305   713.66     62  182129  263  93775   5817
# 5           0   78377    2295   465.62      0  104918  451      0   5817
# 6        6411   94435   49219  1806.49     62  172624  339      0   5865
# 7        6769  112032  177989   526.88     62   34933  373  79200   5817
# 8        6092   92294   85535   201.39     62   64652  264   8335   3585
# 9           0   16279  110755   465.62      0  104447  451      0   5817
# 10       6882   49387   57083     0.00      0  210254  459   2467      0
# 11          0   24677    4485   465.62      0  104728  451      0   5817
# ...

# %% [markdown]
# #### bacon_cano_cnt 帳號&卡號綁一起的交易總次數

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacon_cano_cnt"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_7  latent_9  latent_10  latent_11  latent_12  latent_13  \
# 0  ...     0.294     0.155      0.443      0.222      0.000      0.351
# 1  ...     0.236     0.218      0.493      0.282      0.355      0.678
# 2  ...     0.294     0.155      0.443      0.222      0.000      0.351
#
#    latent_14  latent_15  latent_16  bacon_cano_cnt
# 0        0.0      0.000        0.0              80
# 1        0.0      0.093        0.0              23
# 2        0.0      0.000        0.0              18
#
# [3 rows x 87 columns]

# %% [markdown]
# #### bacno_cano_conam_cumsum_mean 該帳戶該卡號該筆刷卡前所有金額平均

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_conam_cumsum_mean"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_9  latent_10  latent_11  latent_12  latent_13  latent_14  \
# 0  ...     0.155      0.443      0.222      0.000      0.351        0.0
# 1  ...     0.218      0.493      0.282      0.355      0.678        0.0
# 2  ...     0.155      0.443      0.222      0.000      0.351        0.0
#
#    latent_15  latent_16  bacon_cano_cnt  bacno_cano_conam_cumsum_mean
# 0      0.000        0.0              80                       561.301
# 1      0.093        0.0              23                       355.962
# 2      0.000        0.0              18                       552.063
#
# [3 rows x 88 columns]

# %% [markdown]
# #### 2. bacno_cano_7_sleep_time_conam_lower_3000_cnt  帳號卡號最後幾天挑14筆交易的交易時間發生在睡覺時間且金額小於3000的次數

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_7_sleep_time_conam_lower_3000_cnt"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_10  latent_11  latent_12  latent_13  latent_14  latent_15  \
# 0  ...      0.443      0.222      0.000      0.351        0.0      0.000
# 1  ...      0.493      0.282      0.355      0.678        0.0      0.093
# 2  ...      0.443      0.222      0.000      0.351        0.0      0.000
#
#    latent_16  bacon_cano_cnt  bacno_cano_conam_cumsum_mean  \
# 0        0.0              80                       561.301
# 1        0.0              23                       355.962
# 2        0.0              18                       552.063
#
#    bacno_cano_7_sleep_time_conam_lower_3000_cnt
# 0                                             0
# ...

# %% [markdown]
# #### 2. bacno_cano_14_rolling_times_prime_time_fraud_cnt  帳號卡號最近幾筆14筆交易內的交易時間發生在盜刷熱門時段的次數

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_14_rolling_times_prime_time_fraud_cnt"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_11  latent_12  latent_13  latent_14  latent_15  latent_16  \
# 0  ...      0.222      0.000      0.351        0.0      0.000        0.0
# 1  ...      0.282      0.355      0.678        0.0      0.093        0.0
# 2  ...      0.222      0.000      0.351        0.0      0.000        0.0
#
#    bacon_cano_cnt  bacno_cano_conam_cumsum_mean  \
# 0              80                       561.301
# 1              23                       355.962
# 2              18                       552.063
#
#    bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                                             0
# 1                                             1
# ...

# %% [markdown]
# #### 3. bacno_cano_sec_diff_latter 該筆與同帳戶卡號交易後一筆減前一筆的秒數

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_sec_diff_latter"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_12  latent_13  latent_14  latent_15  latent_16  bacon_cano_cnt  \
# 0  ...      0.000      0.351        0.0      0.000        0.0              80
# 1  ...      0.355      0.678        0.0      0.093        0.0              23
# 2  ...      0.000      0.351        0.0      0.000        0.0              18
#
#    bacno_cano_conam_cumsum_mean  bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                       561.301                                             0
# 1                       355.962                                             1
# 2                       552.063                                             0
#
# ...

# %% [markdown]
# #### bacno_cano_no_recent_7_conam_pos_trend 最近7次的交易金額的diff是不是平均為正

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_no_recent_7_conam_pos_trend"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_13  latent_14  latent_15  latent_16  bacon_cano_cnt  \
# 0  ...      0.351        0.0      0.000        0.0              80
# 1  ...      0.678        0.0      0.093        0.0              23
# 2  ...      0.351        0.0      0.000        0.0              18
#
#    bacno_cano_conam_cumsum_mean  bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                       561.301                                             0
# 1                       355.962                                             1
# 2                       552.063                                             0
#
#    bacno_cano_14_rolling_times_prime_time_fraud_cnt  \
# ...

# %% [markdown]
# #### bacno_cano_conam_rolling_7_window_sum 該帳戶該卡號該筆刷卡的包含自己7次金額加總

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_conam_rolling_7_window_sum"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_14  latent_15  latent_16  bacon_cano_cnt  \
# 0  ...        0.0      0.000        0.0              80
# 1  ...        0.0      0.093        0.0              23
# 2  ...        0.0      0.000        0.0              18
#
#    bacno_cano_conam_cumsum_mean  bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                       561.301                                             0
# 1                       355.962                                             1
# 2                       552.063                                             0
#
#    bacno_cano_14_rolling_times_prime_time_fraud_cnt  \
# 0                                              12.0
# ...

# %% [markdown]
# #### bacno_cano_conam_rolling_14_window_sum 該帳戶該卡號該筆刷卡的包含自己14次金額平均

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_conam_rolling_14_window_mean"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_15  latent_16  bacon_cano_cnt  bacno_cano_conam_cumsum_mean  \
# 0  ...      0.000        0.0              80                       561.301
# 1  ...      0.093        0.0              23                       355.962
# 2  ...      0.000        0.0              18                       552.063
#
#    bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                                             0
# 1                                             1
# 2                                             0
#
#    bacno_cano_14_rolling_times_prime_time_fraud_cnt  \
# 0                                              12.0
# 1                                              14.0
# ...

# %% [markdown]
# #### bacno_cano_conam_rolling_7_window_mean 該帳戶該卡號該筆刷卡的包含自己7次金額平均

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_conam_rolling_7_window_mean"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  latent_16  bacon_cano_cnt  bacno_cano_conam_cumsum_mean  \
# 0  ...        0.0              80                       561.301
# 1  ...        0.0              23                       355.962
# 2  ...        0.0              18                       552.063
#
#    bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                                             0
# 1                                             1
# 2                                             0
#
#    bacno_cano_14_rolling_times_prime_time_fraud_cnt  \
# 0                                              12.0
# 1                                              14.0
# ...

# %% [markdown]
# #### bacno_cano_conam_rolling_3_window_mean 該帳戶該卡號該筆刷卡的包含自己3次金額平均

# %%
all_features_13 = pd.concat([all_features_13, all_features_18["bacno_cano_conam_rolling_3_window_mean"]], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  bacon_cano_cnt  bacno_cano_conam_cumsum_mean  \
# 0  ...              80                       561.301
# 1  ...              23                       355.962
# 2  ...              18                       552.063
#
#    bacno_cano_7_sleep_time_conam_lower_3000_cnt  \
# 0                                             0
# 1                                             1
# 2                                             0
#
#    bacno_cano_14_rolling_times_prime_time_fraud_cnt  \
# 0                                              12.0
# 1                                              14.0
# 2                                              10.0
#
# ...

# %% [markdown]
# #### 加入bacno_cano_7_times_conam_max_by_no, bacno_cano_conam_rolling_14_window_max, bacno_cano_14_times_conam_max_by_no, bacno_cano_conam_cumsum_mean, bacno_cano_recent_no_5_loctm_acc_min_diff, bacno_cano_no_mean_loctm_acc_min_diff

# %%
all_features_13 = all_features_13.reset_index(drop=True)

# %%
all_features_13 = pd.concat([all_features_13, other_all_feature], axis=1)
all_features_13.head(3)
# Out:
#    acqic   bacno    cano   conam  csmcu   loctm  mcc  mchno  scity  stocn  \
# 0   6881  113261   38038  513.80      0  172652  457  59333      0    102
# 1      0  134508   45725  465.62      0  105114  451      0   5817    102
# 2   6881   15408  188328  513.80      0  152458  457  59333      0    102
#
#    ...  bacno_cano_conam_rolling_7_window_sum  \
# 0  ...                                3673.51
# 1  ...                                2482.74
# 2  ...                                3892.49
#
#    bacno_cano_conam_rolling_14_window_mean  \
# 0                                  601.579
# 1                                  383.249
# 2                                  568.570
#
#    bacno_cano_conam_rolling_7_window_mean  \
# 0                                 524.787
# 1                                 354.677
# 2                                 556.070
#
#    bacno_cano_conam_rolling_3_window_mean  bacno_cano_7_times_conam_max_by_no  \
# ...

# %% [markdown]
# #### 先刪掉幾個看是誰overfitting

# %%
all_features_13 = all_features_13.drop(["bacno_cano_7_sleep_time_conam_lower_3000_cnt.1",
                                       "bacno_cano_7_times_conam_max", # 跟bacno_cano_7_times_conam_max_by_no重複
                                       # "bacno_cano_no_mean_loctm_acc_min_diff", # 帳戶平均交易時間差 先拿掉看看
                                       "bacno_cano_14_times_conam_mean", # 跟bacno_cano_conam_rolling_14_window_mean重複
                                       # "bacno_cano_7_times_conam_mean",  # 考慮要不要加by no版本
                                       # "bacno_cano_3_times_conam_sum",  # 考慮要不要加by no版本
                                       # "bacno_cano_7_times_conam_sum",  # 考慮要不要加by no版本
                                       "bacno_cano_conam_rolling_7_window_mean", # 會跟bacno_cano_conam_rolling_7_window_sum有點疊到
                                       "bacno_cano_conam_rolling_14_window_mean", # 會跟bacno_cano_conam_rolling_7_window_sum有點疊到
                                       "bacno_cano_conam_cumsum_mean.1" # 跟bacno_cano_conam_cumsum_mean 重複
                                       ], axis=1)

# %% [markdown]
# ### 輸出檔案

# %%
train_pre_2 = all_features_13[:-len(X_test_13)]
test_pre_2 = all_features_13[-len(X_test_13):]

print(train_pre_2.shape)
print(test_pre_2.shape)

train_pre_2 = pd.concat([train_pre_2, train_raw_13["fraud_ind"]], axis=1)

# print(train_pre_2.drop_duplicates().reset_index(drop=True).shape)
# print(train_pre_2.shape)
# Out:
# (1516988, 96)
# (421665, 96)

# %%
train_pre_2.to_csv("train_pre_13_add_more_ftrs_2.csv", index=None)
test_pre_2.to_csv("test_pre_13_add_more_ftrs_2.csv", index=None)
